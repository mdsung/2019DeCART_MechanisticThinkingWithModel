# %% [markdown]
# # Cystic Fibrosis
# * genetic disease
# * Mutation on CFTR - Cl channel

# %% [markdown]
# ## Read the file

# %%
cf <- read.csv("Data/cf.csv")

# %%
head(cf)
names(cf)
# Out:
#   id     YRM  age sex fev1pct pseudo mssa jedate jlastdate jddate dflag1yr
# 1 123462 2010 10  0   91.20   0      0    18508  20453     NA     0
# 2 123462 2011 11  0   88.32   0      0    18704  20453     NA     0
# 3 123462 2012 12  0   87.89   0      1    19019  20453     NA     0
# 4 123462 2013 13  0   92.94   0      1    19446  20453     NA     0
# 5 123462 2014 14  0   85.19   0      1    19782  20453     NA     0
# 6 123462 2015 15  0   72.92   0      0    20189  20453     NA     0
#   dflag5yr survdays dflag
# 1 0        1945     0
# 2 0        1749     0
# 3 0        1434     0
# 4 0        1007     0
# 5 0         671     0
# 6 0         264     0
#  [1] "id"        "YRM"       "age"       "sex"       "fev1pct"   "pseudo"
#  [7] "mssa"      "jedate"    "jlastdate" "jddate"    "dflag1yr"  "dflag5yr"
# [13] "survdays"  "dflag"

# %% [markdown]
# ## Drawing survival graphs

# %%
install.packages("survival", repos='http://cran.us.r-project.org')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(survival)

# %%
plot(survfit(Surv(survdays,dflag) ~1, cf), lwd=3, col="red", xlab="Time", ylab="Fraction alive", cex.axis=1, cex.lab=1)
## The ~ says to treat this survivorship as a function of nothing.
## The ,cf says to use that data.
# Out:
# plot without title

# %% [markdown]
# The Surv function takes the number of days until the last visit and combines that with whether that visit was a death or not, and finds the fraction of peiple alive

# %% [markdown]
# ## Read file with jus the first measurement for each

# %%
cffirst <- read.csv("Data/cffirst.csv")
head(cffirst)
# Out:
#   id     YRM  age  sex fev1pct pseudo mssa jedate jlastdate jddate dflag1yr
# 1 123462 2010 10.0 0    91.20  0      0    18508  20453        NA  0
# 2 123518 2005  6.4 0   115.50  1      0    16663  20453        NA  0
# 3 123550 1994 14.0 0    86.59  0      0    12441  18992     18762  0
# 4 123552 2003  6.9 0    88.93  1      1    15714  20453        NA  0
# 5 123597 1993 54.0 1    60.91  0      1    12085  18992     18842  0
# 6 123605 2008  7.3 0   154.70  1      1    17604  20453        NA  0
#   dflag5yr survdays dflag
# 1 0        1945     0
# 2 0        3790     0
# 3 0        6551     1
# 4 0        4739     0
# 5 0        6907     1
# 6 0        2849     0

# %%
plot(survfit(Surv(survdays,dflag) ~1, cffirst), lwd=3, col="red", xlab="Time", ylab="Fraction alive", cex.axis=1, cex.lab=1)
## The ~ says to treat this survivorship as a function of nothing.
## The ,cffirst says to use that data.
# Out:
# plot without title

# %%
plot(survfit(Surv(survdays,dflag) ~ pseudo, cffirst), lwd=3, col=c("green", "red"), xlab="Time", ylab="Fraction alive", cex.axis=1, cex.lab=1)
legend("topright",c("No pseudo","With pseudo"), lwd=5, col = c("green", "red"))
# Out:
# plot without title

# %%
plot(survfit(Surv(survdays,dflag) ~ mssa, cffirst), lwd=3, col=c("green", "red"), xlab="Time", ylab="Fraction alive", cex.axis=1, cex.lab=1)
legend("topright",c("No MSSA","With MSSA"), lwd=5, col = c("green", "red"))
# Out:
# plot without title

# %% [markdown]
# ## Make a mini file with the first 20 patients to practice

# %%
minicf <- cffirst[1:20,] 
# This says take rows from 1 to 20.
minicf[order(minicf$survdays),]
# Out:
#    id     YRM  age  sex fev1pct pseudo mssa jedate jlastdate jddate dflag1yr
# 15 124092 2015  5.4 1   128.80  0      1    20171  20453        NA  0
# 13 123948 2015  7.0 1    96.07  0      0    20134  20453        NA  0
# 20 124365 2009  8.4 0    98.87  0      0    18227  18627        NA  0
# 9  123731 1987 25.0 1    25.38  1      0     9874  11687     11580  0
# 1  123462 2010 10.0 0    91.20  0      0    18508  20453        NA  0
# 17 124134 2010 11.0 0    64.28  0      1    18368  20453        NA  0
# 7  123658 2010  5.5 0    99.10  0      1    18339  20453        NA  0
# 8  123723 1991 31.0 0    25.14  1      0    11405  14244     14133  0
# 6  123605 2008  7.3 0   154.70  1      1    17604  20453        NA  0
# 19 124358 1992 24.0 1    51.41  1      0    11695  14609     14549  0
# 16 124112 2007  4.8 1   160.20  0      0    17385  20453        NA  0
# 2  123518 2005  6.4 0   115.50  1      0    16663  20453        NA  0
# 10 123801 1996  7.4 1    92.16  0      0    13197  17531        NA  0
# 4  123552 2003  6.9 0    88.93  1      1    15714  20453        NA  0
# 18 124263 2000 16.0 1    35.53  1      0    14659  20453        NA  0
# 11 123836 1998  9.4 1    95.24  1      1    13910  20453        NA  0
# 3  123550 1994 14.0 0    86.59  0      0    12441  18992     18762  0
# 14 124015 1997  8.4 1    68.72  0      0    13622  20453        NA  0
# 5  123597 1993 54.0 1    60.91  0      1    12085  18992     18842  0
# 12 123843 1995  6.8 0    97.48  1      0    12877  20088        NA  0
#    dflag5yr survdays dflag
# 15 0         282     0
# 13 0         319     0
# 20 0         400     0
# 9  1        1813     1
# 1  0        1945     0
# 17 0        2085     0
# 7  0        2114     0
# 8  0        2839     1
# 6  0        2849     0
# 19 0        2914     1
# 16 0        3068     0
# 2  0        3790     0
# 10 0        4334     0
# 4  0        4739     0
# 18 0        5794     0
# 11 0        6543     0
# 3  0        6551     1
# 14 0        6831     0
# 5  0        6907     1
# 12 0        7211     0

# %%
plot(survfit(Surv(survdays,dflag) ~ 1, minicf), mark.time=T, lwd=3, col=c("red"), xlab="Time", ylab="Fraction alive", cex.axis=1, cex.lab=1)
# Out:
# plot without title

# %% [markdown]
# 5단계가 있다는 것은 event가 5회 있었다는 것.
